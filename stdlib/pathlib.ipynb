# %% [markdown]
# # pathlib モジュールメモ
#
# Python標準ライブラリ `pathlib` はファイルパスを直感的に扱えるモジュール。
# 文字列操作よりも安全で読みやすい。
#
# ---

# %%
from pathlib import Path

# %% [markdown]
# ## パスの基本操作 (作成日:2025/08/25)
#
# ### Q1. 現在の作業ディレクトリを表示せよ
# 👉 ヒント: `Path` のメソッド

# %%
# 回答記入欄↓

# %% [markdown]
# <details>
# <summary>解答を見る</summary>
#
# ```python
# print(Path.cwd())
# ```
#
# </details>

# %% [markdown]
# ### Q2. 親ディレクトリを表示せよ

# %%
# 回答記入欄↓

# %% [markdown]
# <details>
# <summary>解答を見る</summary>
#
# ```python
# print(Path.cwd().parent)
# ```
#
# </details>

# %% [markdown]
# ### Q3. カレントディレクトリ直下の "data/sample.csv" のパスを作成せよ

# %%
# 回答記入欄↓

# %% [markdown]
# <details>
# <summary>解答を見る</summary>
#
# ```python
# print(Path.cwd() / "data" / "sample.csv")
# ```
#
# </details>
